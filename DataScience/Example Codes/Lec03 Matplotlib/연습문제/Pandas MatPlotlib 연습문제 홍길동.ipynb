# %% [markdown]
# ### 출력가 나오도록 스크립트를 작성해보세요

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header = 0, index_col = 0)

# %%
summer = df[1].iloc[:,:5]
summer.head(2)
# Out:
#                  0             1             2               3   4
# 0              NaN  Summer Games  Winter Games  Combined Total NaN
# 1  Team (IOC code)             №           NaN             NaN NaN

# %%
summer.columns = ['경기수', '금', '은', '동', '계']
summer.head(2)
# Out:
#                   경기수    금    은    동      계
# Team (IOC code)     №  NaN  NaN  NaN  Total
# Afghanistan (AFG)  14  0.0  0.0  2.0      2

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header = 0, index_col = 0) 
summer = df[1].iloc[:,:5]
#
summer.sort_values('금', ascending = False).head(3)
# Out:
#                                         경기수       금       은       동      계
# Totals                                   28  5116.0  5080.0  5487.0  15683
# United States (USA) [P] [Q] [R] [Z] [F]  27  1022.0   795.0   706.0   2523
# Soviet Union (URS) [URS]                  9   395.0   319.0   296.0   1010

# %%
summer.to_excel('하계올림픽메달.xlsx')

# %%
import pandas as pd
index = pd.date_range('1/1/2000', periods =8)
print(index)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df
# Out:
#                    A         B         C
# 2000-01-01  0.468651  0.170842  0.131028
# 2000-01-02  0.513155  0.102332  0.146409
# 2000-01-03  0.876018  0.261601  0.339652
# 2000-01-04  0.034700  0.614950  0.475924
# 2000-01-05  0.352410  0.124726  0.739433
# 2000-01-06  0.761303  0.599086  0.184917
# 2000-01-07  0.968161  0.906340  0.898252
# 2000-01-08  0.597043  0.069542  0.778404

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
print(df['B'])
# Out:
# 2000-01-01    0.693347
# 2000-01-02    0.554481
# 2000-01-03    0.030172
# 2000-01-04    0.772001
# 2000-01-05    0.404332
# 2000-01-06    0.098032
# 2000-01-07    0.466876
# 2000-01-08    0.228846
# Freq: D, Name: B, dtype: float64

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
print(df['B'] > 0.4)
# Out:
# 2000-01-01    False
# 2000-01-02     True
# 2000-01-03    False
# 2000-01-04     True
# 2000-01-05    False
# 2000-01-06     True
# 2000-01-07    False
# 2000-01-08    False
# Freq: D, Name: B, dtype: bool

# %%
# 불 인덱스
df2
# Out:
#                    A         B         C
# 2000-01-02  0.309201  0.601420  0.888980
# 2000-01-04  0.890955  0.560506  0.072054
# 2000-01-06  0.229378  0.598898  0.079411

# %%
df2 = df2.T
df2
# Out:
#    2000-01-02  2000-01-04  2000-01-06
# A    0.309201    0.890955    0.229378
# B    0.601420    0.560506    0.598898
# C    0.888980    0.072054    0.079411

# %%
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
# A열의 값을 B열의 값으로 나눈 값을 D열에 저장

df
# Out:
#                    A         B         C         D
# 2000-01-01  0.131460  0.980343  0.589542  0.134096
# 2000-01-02  0.945285  0.228944  0.378329  4.128889
# 2000-01-03  0.185192  0.202797  0.137848  0.913192
# 2000-01-04  0.237559  0.080664  0.534866  2.945034
# 2000-01-05  0.090324  0.315251  0.608988  0.286513
# 2000-01-06  0.339838  0.532972  0.671206  0.637628
# 2000-01-07  0.635585  0.690527  0.705970  0.920436
# 2000-01-08  0.331889  0.138351  0.011805  2.398881

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']
#행 우선 계산 값을 E 열에 저장
df.head()
# Out:
#                    A         B         C          D          E
# 2000-01-01  0.748079  0.360310  0.502083   2.076211   3.686682
# 2000-01-02  0.746807  0.017761  0.152632  42.048213  42.965412
# 2000-01-03  0.123465  0.099511  0.030881   1.240721   1.494578
# 2000-01-04  0.372322  0.285157  0.973395   1.305676   2.936550
# 2000-01-05  0.263661  0.157584  0.976748   1.673147   3.071140

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis = 1)
 #A열의 데이터를 기준으로 열 우선 계산
df.head()
# Out:
#               A         B         C         D         E
# 2000-01-01  0.0 -0.440340 -0.618792  2.070019  3.082282
# 2000-01-02  0.0 -0.495373 -0.205743  4.281528  5.447218
# 2000-01-03  0.0  0.300670 -0.248912  0.172605  1.410889
# 2000-01-04  0.0  0.333484  0.324599  0.118835  2.162561
# 2000-01-05  0.0  0.595533  0.425992  0.019446  1.139633

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods =8)
df = pd.DataFrame(np.random.rand(8,3), index = index, columns = list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis = 1)
df = df.sub(df['A'], axis =0)  
#C열의 데이터를 기준으로 열 우선 계산
df.to_csv('test.csv')
df.head()
# Out:
#               A         B    C          D          E
# 2000-01-01  0.0 -0.725177  1.0   9.600651  12.859771
# 2000-01-02 -0.0  1.042877  1.0 -59.009028 -60.181204
# 2000-01-03 -0.0  1.490286  1.0 -46.575352 -48.898810
# 2000-01-04 -0.0 -0.348669  1.0  -0.311326  -6.879253
# 2000-01-05 -0.0 -0.706604  1.0  -0.924645  -6.795200

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df.head()
# Out:
#                                 총인구수  연령구간인구수     0세     1세     2세     3세  \
# 행정구역
# 서울특별시  (1100000000)          9857426  9857426  61253  70532  74322  72482
# 서울특별시 종로구 (1111000000)        154770   154770    652    794    911    895
# 서울특별시 종로구 청운효자동(1111051500)    13272    13272     81     82     90    105
# 서울특별시 종로구 사직동(1111053000)       9441     9441     43     63     75     68
# 서울특별시 종로구 삼청동(1111054000)       2907     2907     12      4     22     13
#
#                                 4세     5세     6세     7세   ...      91세   92세  \
# 행정구역                                                      ...
# 서울특별시  (1100000000)          71688  78941  75386  75929   ...     5892  4695
# 서울특별시 종로구 (1111000000)         859   1046    909   1012   ...      149   115
# 서울특별시 종로구 청운효자동(1111051500)     97    116    117    116   ...       12    14
# 서울특별시 종로구 사직동(1111053000)       76     81     74     83   ...       11    13
# 서울특별시 종로구 삼청동(1111054000)       12     13     20     11   ...        5     2
#
#                               93세   94세   95세   96세   97세   98세  99세  100세 이상
# 행정구역
# 서울특별시  (1100000000)          3589  3501  2569  1851  1436  1010  736     5519
# 서울특별시 종로구 (1111000000)         95    79    81    60    46    37   26      226
# 서울특별시 종로구 청운효자동(1111051500)     7     7     8     3     5     1    1       17
# 서울특별시 종로구 사직동(1111053000)       7     5     7     3     6     4    4       17
# 서울특별시 종로구 삼청동(1111054000)       3     3     2     2     0     2    1        7
#
# [5 rows x 103 columns]

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
# 전체 데이터를 총인구수로 나눠서 비율로 변환
# 총인구수, 연령구간인구수 열 삭제

# %%
name = input('원하는 지역의 이름을 입력해주세요 : ') #2. 지역 이름 입력
a = df.index.str.contains(name) #3. 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]
df2
# Out:
# 원하는 지역의 이름을 입력해주세요 : 삼성
#                                   0세        1세        2세        3세        4세  \
# 행정구역
# 서울특별시 관악구 삼성동(1162074500)   0.003678  0.003940  0.005817  0.005554  0.004616
# 서울특별시 강남구 삼성1동(1168058000)  0.006122  0.006997  0.008410  0.006526  0.007333
# 서울특별시 강남구 삼성2동(1168059000)  0.006909  0.007250  0.007828  0.008611  0.008203
# 대전광역시 동구 삼성동(3011069500)    0.005191  0.006066  0.006442  0.006817  0.008568
# 충청북도 음성군 삼성면(4377035000)    0.003399  0.003922  0.004706  0.004967  0.005359
# 전라북도 익산시 삼성동(4514069000)    0.006151  0.007448  0.008654  0.007990  0.008865
# 경상남도 양산시 삼성동(4833052000)    0.005973  0.006802  0.007586  0.007804  0.006889
#
#                                   5세        6세        7세        8세        9세  \
# 행정구역
# 서울특별시 관악구 삼성동(1162074500)   0.005254  0.004541  0.004879  0.004691  0.005629
# 서울특별시 강남구 삼성1동(1168058000)  0.007737  0.006929  0.006660  0.006324  0.008073
# 서울특별시 강남구 삼성2동(1168059000)  0.010245  0.010211  0.009973  0.009428  0.010585
# 대전광역시 동구 삼성동(3011069500)    0.006504  0.006942  0.008005  0.007942  0.007505
# 충청북도 음성군 삼성면(4377035000)    0.005621  0.004575  0.004967  0.006797  0.005621
# 전라북도 익산시 삼성동(4514069000)    0.011337  0.010885  0.011096  0.011578  0.011036
# 경상남도 양산시 삼성동(4833052000)    0.008022  0.008197  0.007674  0.007325  0.008153
#
#                               ...          91세       92세       93세       94세  \
# 행정구역                          ...
# 서울특별시 관악구 삼성동(1162074500)     ...     0.000976  0.000488  0.000450  0.000638
# 서울특별시 강남구 삼성1동(1168058000)    ...     0.000673  0.000404  0.000538  0.000269
# 서울특별시 강남구 삼성2동(1168059000)    ...     0.000204  0.000374  0.000136  0.000306
# 대전광역시 동구 삼성동(3011069500)      ...     0.000625  0.000938  0.000750  0.000250
# 충청북도 음성군 삼성면(4377035000)      ...     0.001046  0.001046  0.000523  0.000392
# 전라북도 익산시 삼성동(4514069000)      ...     0.000573  0.000241  0.000302  0.000271
# 경상남도 양산시 삼성동(4833052000)      ...     0.000305  0.000523  0.000087  0.000218
#
#                                  95세       96세       97세       98세       99세  \
# 행정구역
# 서울특별시 관악구 삼성동(1162074500)   0.000188  0.000150  0.000188  0.000113  0.000075
# 서울특별시 강남구 삼성1동(1168058000)  0.000202  0.000135  0.000269  0.000135  0.000067
# 서울특별시 강남구 삼성2동(1168059000)  0.000204  0.000170  0.000102  0.000136  0.000034
# 대전광역시 동구 삼성동(3011069500)    0.000500  0.000125  0.000188  0.000000  0.000125
# 충청북도 음성군 삼성면(4377035000)    0.000261  0.000261  0.000131  0.000000  0.000000
# 전라북도 익산시 삼성동(4514069000)    0.000121  0.000121  0.000030  0.000060  0.000000
# 경상남도 양산시 삼성동(4833052000)    0.000000  0.000087  0.000044  0.000000  0.000087
#
#                              100세 이상
# 행정구역
# 서울특별시 관악구 삼성동(1162074500)   0.000863
# 서울특별시 강남구 삼성1동(1168058000)  0.000202
# 서울특별시 강남구 삼성2동(1168059000)  0.000340
# 대전광역시 동구 삼성동(3011069500)    0.000500
# 충청북도 음성군 삼성면(4377035000)    0.000392
# 전라북도 익산시 삼성동(4514069000)    0.000090
# 경상남도 양산시 삼성동(4833052000)    0.000087
#
# [7 rows x 101 columns]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family ='Malgun Gothic')
df2.T.plot()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family ='Malgun Gothic')
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0) 
# ①-1. 전체 데이터를 총인구수로 나눠서 비율로 변환
# ①-2. 총인구수, 연령구간인구수 열 삭제
name = input('원하는 지역의 이름을 입력해주세요 : ')  # ② 지역 이름 입력
# ③ 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]
df.loc[np.power(df.sub(df2.iloc[0], axis = 1), 2).sum(axis = 1).sort_values().index[:5]].T.plot()
plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 : 신림
