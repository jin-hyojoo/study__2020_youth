# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ts = pd.Series(np.random.randn(1000), 
              index=pd.date_range('1/1/2000',periods=1000))

# %%
ts.head(2)
# Out:
# 2000-01-01    0.485198
# 2000-01-02   -0.274323
# Freq: D, dtype: float64

# %%
ts = ts.cumsum()

# %%
ts.plot()
plt.show()

# %%
df = df.cumsum()
plt.figure()
plt.plot()
# Out:
# []

# %%
df = pd.DataFrame(np.random.randn(1000,4), index=ts.index,
                 columns=list('ABCD'))

# %%
df = df.cumsum()
df.head(2)
# Out:
#                    A         B         C         D
# 2000-01-01 -0.684057 -0.586330  1.509023  0.373408
# 2000-01-02 -0.973259 -1.232721  1.861590  0.809177

# %%
plt.figure();
df.plot();

# %%
df2 = pd.DataFrame(np.random.rand(10,4), columns=list('abcd'))

# %%
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %%
df = pd.DataFrame(np.random.rand(10,5), columns=list('ABCDE'))

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.464348   0.417031   0.662570   0.643756   0.615261
# std     0.193507   0.343773   0.298042   0.300875   0.279754
# min     0.167476   0.044861   0.127306   0.057935   0.066253
# 25%     0.293915   0.107833   0.583922   0.460778   0.474312
# 50%     0.545410   0.397751   0.751757   0.693202   0.669479
# 75%     0.620942   0.522557   0.884513   0.901391   0.750775
# max     0.669263   0.984962   0.967623   0.946722   0.968646

# %%
df.plot.box()

# %%
df.plot.box(vert=False)

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Col1', 'Col2'])
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])

# %%
df
# Out:
#        Col1      Col2  X
# 0  0.099480  0.938734  A
# 1  0.929668  0.399747  A
# 2  0.826777  0.337867  A
# 3  0.452800  0.294400  A
# 4  0.298057  0.563982  A
# 5  0.296644  0.375292  B
# 6  0.159690  0.071664  B
# 7  0.651435  0.055914  B
# 8  0.620761  0.477038  B
# 9  0.907923  0.580632  B

# %%
df.boxplot(by='X')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000026229BA6A90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002622A34B550>],
#       dtype=object)
