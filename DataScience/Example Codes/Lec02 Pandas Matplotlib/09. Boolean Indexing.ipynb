# %%
import numpy as np
import pandas as pd

# %% [markdown]
# np.array() , np.arange(), np.linspace(), np.random()

# %%
np.array([1,2,3,4,5]).tolist()
# Out:
# [1, 2, 3, 4, 5]

# %%
np.arange(1, 100, 10)
# Out:
# array([ 1, 11, 21, 31, 41, 51, 61, 71, 81, 91])

# %%
np.linspace(1,3,20)
# Out:
# array([1.        , 1.10526316, 1.21052632, 1.31578947, 1.42105263,
#        1.52631579, 1.63157895, 1.73684211, 1.84210526, 1.94736842,
#        2.05263158, 2.15789474, 2.26315789, 2.36842105, 2.47368421,
#        2.57894737, 2.68421053, 2.78947368, 2.89473684, 3.        ])

# %%
A = np.random.randint(1,100,(3,3)).tolist()

# %%
A.tolist()

# %%
movie = pd.read_csv('data/movie.csv')
movie.head(1)
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  Color  James Cameron                   723.0     178.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
#
#   movie_facebook_likes
# 0                33000
#
# [1 rows x 28 columns]

# %%
type(movie['director_name'])
# Out:
# pandas.core.series.Series

# %%
# boolean indexing, movie의 imdb_score 컬럼값이 8 이상인 데이터만 가져오기

# %%
movie[movie.imdb_score > 8]
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 3     Color  Christopher Nolan                   813.0     164.0
# 17    Color        Joss Whedon                   703.0     173.0
# 27    Color      Anthony Russo                   516.0     147.0
# 43    Color        Lee Unkrich                   453.0     103.0
# 58    Color     Andrew Stanton                   421.0      98.0
# ...     ...                ...                     ...       ...
# 4804  Color          Cary Bell                     NaN      78.0
# 4815  Color      Bill Melendez                    43.0      25.0
# 4822  Color    Amal Al-Agroobi                     NaN      62.0
# 4846  Color         Sut Jhally                    16.0      80.0
# 4875  Color    Martin Scorsese                    71.0     117.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 3                     22000.0                 23000.0      Christian Bale
# ...

# %%
#imdb_score값이 8 이상인 데이터들 카운트

# %%
(movie.imdb_score > 8).sum()
# Out:
# 249

# %%
movie['director_name'][0:10]
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# 5       Andrew Stanton
# 6            Sam Raimi
# 7         Nathan Greno
# 8          Joss Whedon
# 9          David Yates
# Name: director_name, dtype: object

# %%
movie['director_name'].iloc[0:10]
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# 5       Andrew Stanton
# 6            Sam Raimi
# 7         Nathan Greno
# 8          Joss Whedon
# 9          David Yates
# Name: director_name, dtype: object

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')

# %%
movie.head(3)
# Out:
#                                           color   director_name  \
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spectre                                   Color      Sam Mendes
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spectre                                                    602.0     148.0
#
#                                           director_facebook_likes  \
# movie_title
# Avatar                                                        0.0
# Pirates of the Caribbean: At World's End                    563.0
# Spectre                                                       0.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# ...

# %%
director_name = movie.director_name  # movie['director_name']

# %%
director_name[0]
# Out:
# 'James Cameron'

# %%
director_name[0:10]
# Out:
# movie_title
# Avatar                                            James Cameron
# Pirates of the Caribbean: At World's End         Gore Verbinski
# Spectre                                              Sam Mendes
# The Dark Knight Rises                         Christopher Nolan
# Star Wars: Episode VII - The Force Awakens          Doug Walker
# John Carter                                      Andrew Stanton
# Spider-Man 3                                          Sam Raimi
# Tangled                                            Nathan Greno
# Avengers: Age of Ultron                             Joss Whedon
# Harry Potter and the Half-Blood Prince              David Yates
# Name: director_name, dtype: object

# %%
director_name.loc['Avatar':'Harry Potter and the Half-Blood Prince']
# Out:
# movie_title
# Avatar                                            James Cameron
# Pirates of the Caribbean: At World's End         Gore Verbinski
# Spectre                                              Sam Mendes
# The Dark Knight Rises                         Christopher Nolan
# Star Wars: Episode VII - The Force Awakens          Doug Walker
# John Carter                                      Andrew Stanton
# Spider-Man 3                                          Sam Raimi
# Tangled                                            Nathan Greno
# Avengers: Age of Ultron                             Joss Whedon
# Harry Potter and the Half-Blood Prince              David Yates
# Name: director_name, dtype: object

# %%
director_name.iloc[0:10]
# Out:
# movie_title
# Avatar                                            James Cameron
# Pirates of the Caribbean: At World's End         Gore Verbinski
# Spectre                                              Sam Mendes
# The Dark Knight Rises                         Christopher Nolan
# Star Wars: Episode VII - The Force Awakens          Doug Walker
# John Carter                                      Andrew Stanton
# Spider-Man 3                                          Sam Raimi
# Tangled                                            Nathan Greno
# Avengers: Age of Ultron                             Joss Whedon
# Harry Potter and the Half-Blood Prince              David Yates
# Name: director_name, dtype: object

# %%
movie['director_name'].head(5)
# Out:
# movie_title
# Avatar                                            James Cameron
# Pirates of the Caribbean: At World's End         Gore Verbinski
# Spectre                                              Sam Mendes
# The Dark Knight Rises                         Christopher Nolan
# Star Wars: Episode VII - The Force Awakens          Doug Walker
# Name: director_name, dtype: object

# %%
movie.loc['Avatar':'Spectre']
# Out:
#                                           color   director_name  \
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spectre                                   Color      Sam Mendes
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spectre                                                    602.0     148.0
#
#                                           director_facebook_likes  \
# movie_title
# Avatar                                                        0.0
# Pirates of the Caribbean: At World's End                    563.0
# Spectre                                                       0.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# ...

# %%
movie.iloc[0:3]
# Out:
#                                           color   director_name  \
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spectre                                   Color      Sam Mendes
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spectre                                                    602.0     148.0
#
#                                           director_facebook_likes  \
# movie_title
# Avatar                                                        0.0
# Pirates of the Caribbean: At World's End                    563.0
# Spectre                                                       0.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# ...

# %%
movie.iloc[0:3, 0:2]
# Out:
#                                           color   director_name
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spectre                                   Color      Sam Mendes

# %%
movie.iloc[0:3, [0, 2]]
# Out:
#                                           color  num_critic_for_reviews
# movie_title
# Avatar                                    Color                   723.0
# Pirates of the Caribbean: At World's End  Color                   302.0
# Spectre                                   Color                   602.0

# %%
criteria1 = movie.imdb_score > 8
criteria2 = movie.content_rating == 'PG-13'
criteria3 = (movie.title_year < 2000) | (movie.title_year>=2010)

# %%
criteia3_final = criteria1 & criteria2 & criteria3

# %%
movie[criteia3_final].head()
# Out:
#                             color      director_name  num_critic_for_reviews  \
# movie_title
# The Dark Knight Rises       Color  Christopher Nolan                   813.0
# The Avengers                Color        Joss Whedon                   703.0
# Captain America: Civil War  Color      Anthony Russo                   516.0
# Guardians of the Galaxy     Color         James Gunn                   653.0
# Interstellar                Color  Christopher Nolan                   712.0
#
#                             duration  director_facebook_likes  \
# movie_title
# The Dark Knight Rises          164.0                  22000.0
# The Avengers                   173.0                      0.0
# Captain America: Civil War     147.0                     94.0
# Guardians of the Galaxy        121.0                    571.0
# Interstellar                   169.0                  22000.0
#
#                             actor_3_facebook_likes        actor_2_name  \
# movie_title
# ...

# %%
filtered = movie.loc[criteia3_final, ['imdb_score','content_rating','title_year']]
filtered.head(10)
# Out:
#                                     imdb_score content_rating  title_year
# movie_title
# The Dark Knight Rises                      8.5          PG-13      2012.0
# The Avengers                               8.1          PG-13      2012.0
# Captain America: Civil War                 8.2          PG-13      2016.0
# Guardians of the Galaxy                    8.1          PG-13      2014.0
# Interstellar                               8.6          PG-13      2014.0
# Inception                                  8.8          PG-13      2010.0
# The Martian                                8.1          PG-13      2015.0
# Jurassic Park                              8.1          PG-13      1993.0
# Forrest Gump                               8.8          PG-13      1994.0
# Indiana Jones and the Last Crusade         8.3          PG-13      1989.0

# %%
filtered.to_csv('movie_filtered.csv')

# %%
slb = pd.read_csv('data/slb_stock.csv')
slb.head()
# Out:
#          Date   Open   High    Low  Close    Volume
# 0  2010-01-04  66.39  67.20  66.12  67.11   5771234
# 1  2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2  2010-01-06  67.17  68.94  67.03  68.80   9949946
# 3  2010-01-07  68.49  69.81  68.21  69.51   7700297
# 4  2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
slb = slb.reset_index()
#slb.set_index('Date')

# %%
slb.head()
# Out:
#          Date   Open   High    Low  Close    Volume
# 0  2010-01-04  66.39  67.20  66.12  67.11   5771234
# 1  2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2  2010-01-06  67.17  68.94  67.03  68.80   9949946
# 3  2010-01-07  68.49  69.81  68.21  69.51   7700297
# 4  2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
slb = slb.set_index('Date')

# %%
slb.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  66.39  67.20  66.12  67.11   5771234
# 2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2010-01-06  67.17  68.94  67.03  68.80   9949946
# 2010-01-07  68.49  69.81  68.21  69.51   7700297
# 2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
slb_close = slb['Close']

# %%
slb_summary = slb_close.describe(percentiles=[.1,.9])
slb_summary
# Out:
# count    1895.000000
# mean       79.121905
# std        11.767802
# min        51.750000
# 10%        64.892000
# 50%        78.000000
# 90%        93.248000
# max       117.950000
# Name: Close, dtype: float64

# %%
lower_10 = slb_summary.loc['10%'] 
upper_10 = slb_summary.loc['90%']

# %%
criteria = (slb_close<lower_10) | (slb_close>upper_10)
slb_top_bottom_10 = slb_close[criteria]

# %%
import matplotlib.pyplot as plt

# %%
slb_close.plot(color = 'b', figsize=(12,6))
plt.fill_between(criteria.index, lower_10, slb_close.values)
plt.fill_between(criteria.index, lower_10, slb_close.values,
                where = slb_close<lower_10, color='y')
plt.fill_between(criteria.index, upper_10, slb_close.values,
                where = slb_close>upper_10, color='y')
